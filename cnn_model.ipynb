# %%
from cnn_model import *

# %%
df1, df2 = load_data()
df1, df2 = resample_data(df1, df2, t='100L') # частота дискретизации 10 Гц (раз в 100 мс) 
x_train_std, x_test_std, y_train, y_test = get_preprocessed_data(df1, df2)
# Out:
# ............... Datasets loaded.
# ............... Resampling completed.
# New data dims: X: (5000, 1065, 3), y: (5000,)
# ............... Data preprocessing completed.

# %%
cnn_modeling(x_train_std, x_test_std, y_train, y_test)
# Out:
# WARNING:tensorflow:From c:\users\martavic\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\users\martavic\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 3200 samples, validate on 800 samples
# Epoch 1/50
# 3200/3200 [==============================] - 26s 8ms/step - loss: 0.7067 - accuracy: 0.5053 - val_loss: 0.6773 - val_accuracy: 0.6125
# Epoch 2/50
# 3200/3200 [==============================] - 18s 6ms/step - loss: 0.6406 - accuracy: 0.6447 - val_loss: 0.6153 - val_accuracy: 0.6662
# Epoch 3/50
# 3200/3200 [==============================] - 18s 6ms/step - loss: 0.5835 - accuracy: 0.6953 - val_loss: 0.5567 - val_accuracy: 0.7600
# Epoch 4/50
# ...
